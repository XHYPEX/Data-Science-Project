# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Data/GlobalTemperatures.csv")

# %%
df
# Out:
#       index          dt  LandAverageTemperature  \
# 0         0  1750-01-01                   3.034
# 1         1  1750-02-01                   3.083
# 2         2  1750-03-01                   5.626
# 3         3  1750-04-01                   8.490
# 4         4  1750-05-01                  11.573
# ...     ...         ...                     ...
# 3187   3187  2015-08-01                  14.755
# 3188   3188  2015-09-01                  12.999
# 3189   3189  2015-10-01                  10.801
# 3190   3190  2015-11-01                   7.433
# 3191   3191  2015-12-01                   5.518
#
#       LandAverageTemperatureUncertainty  LandMaxTemperature  \
# 0                                 3.574                 NaN
# 1                                 3.702                 NaN
# 2                                 3.076                 NaN
# 3                                 2.451                 NaN
# 4                                 2.072                 NaN
# ...

# %%
df.describe()
# Out:
#              index  LandAverageTemperature  LandAverageTemperatureUncertainty  \
# count  3192.000000             3180.000000                        3180.000000
# mean   1595.500000                8.374731                           0.938468
# std     921.595356                4.381310                           1.096440
# min       0.000000               -2.080000                           0.034000
# 25%     797.750000                4.312000                           0.186750
# 50%    1595.500000                8.610500                           0.392000
# 75%    2393.250000               12.548250                           1.419250
# max    3191.000000               19.021000                           7.880000
#
#        LandMaxTemperature  LandMaxTemperatureUncertainty  LandMinTemperature  \
# count         1992.000000                    1992.000000         1992.000000
# mean            14.350601                       0.479782            2.743595
# ...

# %%
df
# Out:
#       index          dt  LandAverageTemperature  \
# 0         0  1750-01-01                   3.034
# 1         1  1750-02-01                   3.083
# 2         2  1750-03-01                   5.626
# 3         3  1750-04-01                   8.490
# 4         4  1750-05-01                  11.573
# ...     ...         ...                     ...
# 3187   3187  2015-08-01                  14.755
# 3188   3188  2015-09-01                  12.999
# 3189   3189  2015-10-01                  10.801
# 3190   3190  2015-11-01                   7.433
# 3191   3191  2015-12-01                   5.518
#
#       LandAverageTemperatureUncertainty  LandMaxTemperature  \
# 0                                 3.574                 NaN
# 1                                 3.702                 NaN
# 2                                 3.076                 NaN
# 3                                 2.451                 NaN
# 4                                 2.072                 NaN
# ...
